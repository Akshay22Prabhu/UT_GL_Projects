# %%
import pandas as pd

# %%
data = {
        'Name' : ['Ajay','Akshay'],
        'Age' : ['34','30'],
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name Age
# 0    Ajay  34
# 1  Akshay  30

# %%
df.quantile(0.75) - df.quantile(0.25)
# Out:
# Series([], dtype: float64)

# %%
df.quantile([0.75,0.25])
# Out:
# Empty DataFrame
# Columns: []
# Index: [0.75, 0.25]
